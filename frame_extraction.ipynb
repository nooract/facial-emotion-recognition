# %% [markdown]
# <a href="https://colab.research.google.com/github/nooract/facial-emotion-recognition/blob/main/frame_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import glob
from google.colab import drive

# %%
folders = glob.glob('/content/drive/MyDrive/dataset/concentrating')

# %%
videonames_list = []
for folder in folders:
    for f in glob.glob(folder+'/*.mp4'):
      videonames_list.append(f)
      print(f)
# Out:
# /content/drive/MyDrive/dataset/concentrating/S031_024.mp4
# /content/drive/MyDrive/dataset/concentrating/S001_007.mp4
# /content/drive/MyDrive/dataset/concentrating/S001_013.mp4
# /content/drive/MyDrive/dataset/concentrating/S001_008.mp4
# /content/drive/MyDrive/dataset/concentrating/S001_012.mp4
# /content/drive/MyDrive/dataset/concentrating/S002_012.mp4
# /content/drive/MyDrive/dataset/concentrating/S002_014.mp4
# /content/drive/MyDrive/dataset/concentrating/S003_014.mp4
# /content/drive/MyDrive/dataset/concentrating/S006_031.mp4
# /content/drive/MyDrive/dataset/concentrating/S007_015.mp4
# /content/drive/MyDrive/dataset/concentrating/S007_014.mp4
# /content/drive/MyDrive/dataset/concentrating/S008_019.mp4
# /content/drive/MyDrive/dataset/concentrating/S009_012.mp4
# /content/drive/MyDrive/dataset/concentrating/S009_022.mp4
# /content/drive/MyDrive/dataset/concentrating/S010_010.mp4
# /content/drive/MyDrive/dataset/concentrating/S010_011.mp4
# ...

# %%
print('There are {} videos in Folder'.format(len(videonames_list)))
# Out:
# There are 60 videos in Folder

# %%
count = 0
for i in range(0,len(videonames_list)):
  video_data = videonames_list[i]
  video = cv2.VideoCapture(video_data)
  success = True
  while success:
    success,image = video.read()
    name = '/content/drive/MyDrive/dataset/concentrating_frames/'+str(count)+'.jpg'
    if success == True:
      cv2.imwrite(name,image)
      print('Frame {} Extracted Successfully'.format(count))
      count+=1
    else:
      i = i+1  
    i = i+1
  print('\n\n\nVideo {} Extracted Successfully\n\n\n'.format(video_data))
# Out:
# Streaming output truncated to the last 5000 lines.
# Frame 5955 Extracted Successfully
# Frame 5956 Extracted Successfully
# Frame 5957 Extracted Successfully
# Frame 5958 Extracted Successfully
# Frame 5959 Extracted Successfully
# Frame 5960 Extracted Successfully
# Frame 5961 Extracted Successfully
# Frame 5962 Extracted Successfully
# Frame 5963 Extracted Successfully
#
#
#
# Video /content/drive/MyDrive/dataset/concentrating/S012_010.mp4 Extracted Successfully
#
#
#
# Frame 5964 Extracted Successfully
# Frame 5965 Extracted Successfully
# Frame 5966 Extracted Successfully
# Frame 5967 Extracted Successfully
# Frame 5968 Extracted Successfully
# Frame 5969 Extracted Successfully
# Frame 5970 Extracted Successfully
# Frame 5971 Extracted Successfully
# Frame 5972 Extracted Successfully
# Frame 5973 Extracted Successfully
# Frame 5974 Extracted Successfully
# Frame 5975 Extracted Successfully
# Frame 5976 Extracted Successfully
# Frame 5977 Extracted Successfully
# ...
